# %% [markdown]
# ### Logic flow
# * Single-unit tuning
# * Population PCA by stim (shape) and context (boundary)
# * Cross-context decoding
# * RDMs

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns, scipy.stats as stats
from utils import plot_style, norm01, stim_cmap, stim_axis; plot_style('poster');
# %matplotlib widget
# %matplotlib inline

from sklearn.decomposition import PCA
from matplotlib.colors import Normalize
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler; from sklearn.pipeline import make_pipeline
from sklearn.model_selection import StratifiedKFold, cross_val_score
from scipy.spatial.distance import pdist, squareform

# %% [markdown]
# variables & functions

# %%
conds, thresholds = ['C1', 'C2', 'C3'], [0.25, 0.50, 0.75]

# def save_pca_html(pca_df, thresholds, category, category2label, space, out_dir='../../outputs/figs/presentations/lab_mtngs'):
#     # plotly is optional; skip the interactive export rather than crash if it isn't installed
#     try:
#         import plotly.graph_objects as go
#     except ModuleNotFoundError:
#         print('plotly not installed — skipping interactive HTML export')
#         return
#     import numpy as np, matplotlib.colors as mcolors
#     plotly_markers = {0.25: 'square', 0.50: 'circle', 0.75: 'diamond'}
#     # hue marks context, lightness carries stimulus, so the interactive view reads like the static panels
#     plotly_scales = {thresh: [[x, mcolors.to_hex(stim_cmap(base)(x))] for x in np.linspace(0, 1, 32)]
#                      for thresh, base in zip(thresholds, ['orangered', 'gray', 'deepskyblue'])}
#     pfig = go.Figure()
#     for thresh in thresholds:
#         cond_df = pca_df[pca_df['boundary'] == thresh]
#         pfig.add_trace(go.Scatter3d(
#             x=cond_df['PC1'], y=cond_df['PC2'], z=cond_df['PC3'],
#             mode='markers',
#             marker=dict(size=5, color=cond_df[category], colorscale=plotly_scales[thresh], opacity=0.9,
#                         symbol=plotly_markers[thresh]),
#             name=f'b={thresh:.2f}'
#         ))
#     pfig.update_layout(title=f'color = {category2label[category]}',
#                        scene=dict(xaxis_title='PC1', yaxis_title='PC2', zaxis_title='PC3'))
#     pfig.write_html(f'{out_dir}/PCA_{category2label[category]}_{space}.html')

# %%
inference_df = pd.read_csv('../../outputs/simulations/inference_df.csv')
# stim expressed relative to the context boundary, so it's comparable across contexts
inference_df['stim_aligned'] = inference_df['stim'] - inference_df['boundary']
print(f'len(inference_df) = n_nets * len(eval_df) = {len(inference_df)}')
inference_df.head()
# Out:
# len(inference_df) = n_nets * len(eval_df) = 7200
#   condition   stim  boundary  cond_unique_stim_idx  class  trial_id  rep  \
# 0        C2  0.025       0.5                     0      0         0    9
# 1        C2  0.025       0.5                     0      0         0   12
# 2        C2  0.025       0.5                     0      0         0    8
# 3        C2  0.025       0.5                     0      0         0    1
# 4        C2  0.075       0.5                     1      0         1    9
#
#    stim_noised train/test  pos_pred  class_pred  net_idx  stim_aligned  \
# 0    -0.002915       eval  0.214006         0.0        0        -0.475
# 1     0.069071       eval  0.256972         0.0        0        -0.475
# 2     0.079710       eval  0.263322         0.0        0        -0.475
# 3    -0.018644       eval  0.204619         0.0        0        -0.475
# 4     0.103147       eval  0.277310         0.0        0        -0.425
#
#    resp_aligned
# 0     -0.285994
# ...

# %%
hidden_stack = np.load('../../outputs/simulations/hidden_stack.npy'); print(f'hidden_stack (n_nets, n_eval_trials, n_units): {hidden_stack.shape}')  # (n_nets, n_trials, n_units)
# Out:
# hidden_stack (n_nets, n_eval_trials, n_units): (30, 240, 10)

# %%
# collapse the 4 noised eval reps per trial by averaging — trial-averaging, like averaging repeated stim presentations in neural data
sess0 = inference_df[inference_df['net_idx'] == 0].reset_index(drop=True)
uniq_tid, inv = np.unique(sess0['trial_id'].values, return_inverse=True)
hidden_stack_avg = np.stack([hidden_stack[:, inv == k, :].mean(axis=1) for k in range(len(uniq_tid))], axis=1)  # (n_nets, n_trials, n_units)
print(f'hidden_stack_avg (n_nets, n_trials, n_units): {hidden_stack_avg.shape}')

all_nets_mean_rep = hidden_stack_avg.mean(axis=0)  # also average across nets for the PCA view (pseudo-population / mega-subject)
print(f'all_nets_mean_rep (n_trials, n_units): {all_nets_mean_rep.shape}') # trials x units
# Out:
# hidden_stack_avg (n_nets, n_trials, n_units): (30, 60, 10)
# all_nets_mean_rep (n_trials, n_units): (60, 10)

# %% [markdown]
# ### 1. Single-Unit

# %%
# # Plot all neurons (no averaging) in a grid, with user-defined number of networks
# n_nets_to_plot = 5  # Change this to plot a different number of networks

# n_nets, n_trials, n_units = hidden_stack.shape
# all_neurons = hidden_stack[:n_nets_to_plot].transpose(0, 2, 1).reshape(-1, n_trials)  # shape: (n_nets_to_plot*n_units, 60)

# cond_colors = {0.25: '#e07b39', 0.50: '#5b8db8', 0.75: '#6abf69'}

# # Prepare trial info for coloring
# trial_info = pca_df[['boundary', 'stim']].reset_index(drop=True)

# n_rows = n_nets_to_plot
# n_cols = n_units
# fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols*2.4, n_rows*2.4), sharex=True)
# axes = axes.flatten()

# for idx, ax in enumerate(axes):
#     if idx >= all_neurons.shape[0]:
#         ax.axis('off')
#         continue
#     neuron_act = all_neurons[idx]
#     for bound in bounds:
#         mask = trial_info['boundary'] == bound
#         ax.scatter(trial_info.loc[mask, 'stim'], neuron_act[mask],
#                    color=cond_colors[bound], s=10, alpha=0.7)
#         ax.axvline(bound, color=cond_colors[bound], linestyle='--', linewidth=1, alpha=0.8)
#     ax.set_title(f'Net {idx // n_units + 1}, Unit {idx % n_units + 1}', fontsize=7)
#     ax.set_xlim(0, 1)
#     ax.tick_params(axis='y', labelsize=6)
#     if idx % n_cols == 0:
#         ax.set_ylabel('Activation', fontsize=6)
#     if idx // n_cols == n_rows - 1:
#         ax.set_xlabel('Stim pos', fontsize=6)

# legend_handles = [
#     plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=cond_colors[bound],
#                markersize=7, label=f'b={bound:.2f}')
#     for bound in bounds
# ]
# fig.legend(handles=legend_handles, loc='upper right', fontsize=8, frameon=False,
#            bbox_to_anchor=(1.0, 1.0))
# plt.suptitle(f'Single-neuron tuning (first {n_nets_to_plot} networks)')
# plt.tight_layout()
# plt.show()

# %%
# # --- Neuron Selectivity Quantification (robust, warnings handled) ---
# import statsmodels.api as sm
# from statsmodels.formula.api import ols
# import warnings

# # Data preparation
# n_nets, n_trials, n_units = hidden_stack.shape
# trial_info = pca_df[['boundary', 'class']].reset_index(drop=True)
# trial_info = trial_info.rename(columns={'class': 'class_label'})

# selectivity_types = ['conjunctive', 'mixed', 'class', 'context', 'non-selective']
# selectivity_counts = {k: 0 for k in selectivity_types}
# selectivity_assignments = []
# skipped_neurons = 0

# for net in range(n_nets):
#     for unit in range(n_units):
#         neuron_act = hidden_stack[net, :, unit]
#         df = trial_info.copy()
#         df['activation'] = neuron_act
        
#         try:
#             with warnings.catch_warnings():
#                 warnings.simplefilter('ignore')
#                 model = ols('activation ~ C(class_label) + C(boundary) + C(class_label):C(boundary)', data=df).fit()
#                 anova_table = sm.stats.anova_lm(model, typ=2)
#             p_class = anova_table.loc['C(class_label)', 'PR(>F)']
#             p_context = anova_table.loc['C(boundary)', 'PR(>F)']
#             p_interaction = anova_table.loc['C(class_label):C(boundary)', 'PR(>F)']
            
#             # Assign mutually exclusive category
#             if p_interaction < 0.05: selectivity = 'conjunctive'
#             elif p_class < 0.05 and p_context < 0.05: selectivity = 'mixed'
#             elif p_class < 0.05: selectivity = 'class'
#             elif p_context < 0.05: selectivity = 'context'
#             else: selectivity = 'non-selective'
            
#             selectivity_counts[selectivity] += 1
#             selectivity_assignments.append(selectivity)
        
#         except Exception as e:
#             skipped_neurons += 1
#             selectivity_assignments.append('skipped')
#             continue

# # Quantification
# n_total = n_nets * n_units
# selectivity_props = {k: v / n_total for k, v in selectivity_counts.items()}

# # Results summary
# print('Neuron selectivity quantification:')
# print('Type\tCount\tProportion')
# for k in selectivity_types:
#     print(f'{k}\t{selectivity_counts[k]}\t{selectivity_props[k]:.3f}')
# if skipped_neurons > 0:
#     print(f'Skipped neurons due to model errors: {skipped_neurons}')

# # Optional: Bar plot
# plt.figure(figsize=(5, 3))
# plt.bar(selectivity_types, [selectivity_counts[k] for k in selectivity_types], color='skyblue')
# plt.ylabel('Neuron count')
# plt.title('Neuron selectivity distribution')
# plt.show()

# %% [markdown]
# ### 2. Population: PCA

# %%
# one session's metadata, trial-averaged to align with hidden_stack_avg (sorted by trial_id, as np.unique returns above)
sess_df = (inference_df[inference_df['net_idx'] == 0]
           .groupby('trial_id', sort=True)
           .agg(boundary=('boundary', 'first'), stim=('stim', 'first'),
                stim_noised=('stim_noised', 'mean'),  # 4-rep mean = trial-averaged perceived stim
                **{'class': ('class', 'first')},
                cond_unique_stim_idx=('cond_unique_stim_idx', 'first'),
                stim_aligned=('stim_aligned', 'first'))
           .reset_index())

# stim that overlap across contexts
overlap_stim_ids = (sess_df['stim'] >= 0.25) & (sess_df['stim'] <= 0.75)

pca_df, pca_mtx = sess_df, all_nets_mean_rep  # default to full data for PCA
# pca_df, pca_mtx = sess_df[overlap_stim_ids].reset_index(drop=True), all_nets_mean_rep[overlap_stim_ids.values] # subset to overlapping stim for PCA

# %%
pca = PCA(n_components=3); pcs = pca.fit_transform(pca_mtx)
pca_df['PC1'], pca_df['PC2'], pca_df['PC3'] = pcs[:, 0], pcs[:, 1], pcs[:, 2]
explained_var = pca.explained_variance_ratio_; print('Explained variance by PC (original space):')
for i, var in enumerate(explained_var, 1):    print(f'  PC{i}: {var*100:.2f}%')

shared_norm = Normalize(vmin=pca_df['stim'].min(), vmax=pca_df['stim'].max())
# Out:
# Explained variance by PC (original space):
#   PC1: 97.98%
#   PC2: 1.83%
#   PC3: 0.15%

# %%
dims2or3 = ['3D', '2D'][1]
cond_cmaps = dict(zip(thresholds, [stim_cmap(c) for c in ['orangered', 'gray', 'deepskyblue']]))
view_elev, view_azim = 36, -78
norm = Normalize(vmin=pca_df['stim'].values.min(), vmax=pca_df['stim'].values.max())

fig = plt.figure(figsize=(8,4))

if dims2or3 == '3D':
    pc_cols = ['PC1', 'PC2', 'PC3'] 
    ax = fig.add_subplot(111, projection='3d') 
    ax.set(title=f'Simulations', xlabel=pc_cols[0], ylabel=pc_cols[1], zlabel=pc_cols[2])
    ax.grid(False); ax.view_init(elev=view_elev, azim=view_azim)
    for thresh in thresholds:
        cond_df = pca_df[pca_df['boundary'] == thresh]
        ax.scatter(cond_df[pc_cols[0]], cond_df[pc_cols[1]], cond_df[pc_cols[2]],c=cond_cmaps[thresh](norm(cond_df['stim'].values)), s=55, alpha=0.9, label=f'b={thresh:.2f}')
        ax.scatter(*cond_df[pc_cols].mean(), marker='x', color='k', s=120, linewidth=2.5, zorder=5)  # centroid
    ax.tick_params(labelsize=14, pad=8)
    for axis, labelpad in zip([ax.xaxis, ax.yaxis, ax.zaxis], [25, 25, 55]):
        axis.set_major_locator(plt.MaxNLocator(3)); axis.label.set_size(20); axis.pane.fill = False; axis.pane.set_edgecolor('none'); axis.labelpad=labelpad

else:
    pc_cols = ['PC1', 'PC2']
    ax = fig.add_subplot(111)
    ax.set(title=f'Simulations', xlabel=pc_cols[0], ylabel=pc_cols[1])
    for thresh in thresholds:
        cond_df = pca_df[pca_df['boundary'] == thresh]
        ax.scatter(cond_df[pc_cols[0]], cond_df[pc_cols[1]],c=cond_cmaps[thresh](norm(cond_df['stim'].values)), s=55, alpha=0.9, label=f'b={thresh:.2f}')
        ax.scatter(*cond_df[pc_cols].mean(), marker='x', color='k', s=120, linewidth=2.5, zorder=5)  # centroid
        if thresh==.5:
            cbar = plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cond_cmaps[thresh].reversed()), ax=ax, pad=.02, shrink=1)
            cbar.set_label('Stimulus ->', rotation=270, labelpad=25); cbar.set_ticks([])

plt.subplots_adjust(right=0.75, bottom=0.22 if dims2or3 == '3D' else None)
# plt.savefig(f'../../outputs/figs/presentations/ccn/poster/pca_{dims2or3}.svg', format='svg')  # poster fig on disk kept as is
plt.show()

# %% [markdown]
# ### 3. Population: Cross-Context Decoding
# Train decoder on one context, test on another, for all context pairs. The resulting matrix shows decoding accuracy for each (train, test) context pair, using the midpoint (stim > 0.5 vs < 0.5) as the label. Diagonal: within-context; off-diagonal: cross-context generalization.

# %%
# same decoder as neur5: scaler inside the pipeline (fit on training data only) + default L2, which converges where penalty=None doesn't
clf = make_pipeline(StandardScaler(), LogisticRegression())
cv  = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

def decode_grid(X, y, groups, thresholds):
    """Train a decoder per context, test on every context -> (n_thresh, n_thresh) accuracy grid."""
    acc = np.zeros((len(thresholds), len(thresholds)))
    for i, ctx_tr in enumerate(thresholds):
        train_idx = groups == ctx_tr
        clf.fit(X[train_idx], y[train_idx])
        for j, ctx_te in enumerate(thresholds):
            test_idx = groups == ctx_te
            # scoring on the training trials themselves would read ~100%; cross-validate the diagonal so it means within-context generalization, comparable to off-diag
            if i == j: acc[i, j] = cross_val_score(clf, X[test_idx], y[test_idx], cv=cv, scoring='accuracy').mean()
            else: acc[i, j] = clf.score(X[test_idx], y[test_idx])
    return acc

# %%
# Context-pairwise midpoint decoding with Logistic Regression: train on one context, test on another
n_nets = hidden_stack_avg.shape[0]
ctx_labels = conds

# label from the (trial-averaged) noised stim the network actually saw; the clean stim isn't recoverable from the representation
y = (sess_df['stim_noised'] > 0.5).astype(int).values
groups = sess_df['boundary'].values

pairwise_acc = np.stack([decode_grid(hidden_stack_avg[net], y, groups, thresholds) for net in range(n_nets)])
mean_net_acc = pairwise_acc.mean(axis=0)

plt.figure(figsize=(4.5,4))
sns.heatmap(mean_net_acc, annot=True, fmt='.2f', annot_kws={'size': 17}, xticklabels=ctx_labels, yticklabels=ctx_labels, cmap='plasma_r', vmin=.8, vmax=1)
plt.tick_params(labelsize=17); plt.xlabel('Test context'); plt.ylabel('Train context')
plt.gcf().axes[-1].tick_params(labelsize=17)
plt.tight_layout(); plt.show()

# %% [markdown]
# ### 3b. Context shift along the stimulus axis
# Stimulus axis = one population vector: per unit, the lin-reg slope of activity vs stim across all trials pooled. Sweep a scalar α: shift all of context 0.25 by +α·axis and all of context 0.75 by −α·axis (context 0.5 untouched). One constant vector per context, so a trial's shift never depends on its own stim. Find α* that maximises cross-context off-diagonal decoding accuracy, then recompute the CCD grid on the shifted reps.

# %%
# population stim axis: slope of each unit vs stim across all trials pooled -> the direction the population moves as stim increases
pop_stim_axis = stim_axis(pca_mtx, pca_df['stim'].values)

def shift_contexts(mtx, alpha):
    """Slide all of context 0.25 by +alpha and all of context 0.75 by -alpha along the stim axis (context 0.5 untouched)."""
    shifted = mtx.copy()
    shifted[(pca_df['boundary'] == 0.25).values] += alpha * pop_stim_axis
    shifted[(pca_df['boundary'] == 0.75).values] -= alpha * pop_stim_axis
    return shifted

# label from the noised stim the network actually saw; the clean stim isn't recoverable from the representation
y = (pca_df['stim_noised'] > 0.5).astype(int).values
groups = pca_df['boundary'].values
offdiag_mask = ~np.eye(len(thresholds), dtype=bool)

def offdiag_acc(mtx):    return decode_grid(mtx, y, groups, thresholds)[offdiag_mask].mean()

alphas = np.linspace(0, 1, 50)
accs = np.array([offdiag_acc(shift_contexts(pca_mtx, alpha)) for alpha in alphas])

best_alpha = alphas[np.argmax(accs)]
print(f"Best α={best_alpha:.3f}, off-diag accuracy={np.max(accs)*100:.2f}%")
# Out:
# Best α=0.082, off-diag accuracy=99.17%

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.set(xlabel='Remove dissimilarity along\nstimulus axis', ylabel='Accuracy', xlim=(0,.5), xticks=np.arange(0, 0.55, 0.1))#, title='Cross-context decoding')
ax.plot(alphas, accs * 100)
ax.axvline(best_alpha, color='r', ls='--', label=f'α*={best_alpha:.2f}')
plt.tight_layout(); plt.show()

# %%
# apply best_alpha and compute cross-context decoding on the corrected reps
pca_mtx_opt = shift_contexts(pca_mtx, best_alpha)
acc_opt = decode_grid(pca_mtx_opt, y, groups, thresholds)

ctx_labels = conds
plt.figure(figsize=(4.5, 4))
sns.heatmap(acc_opt, annot=True, fmt='.2f', annot_kws={'size': 17}, xticklabels=ctx_labels, yticklabels=ctx_labels, cmap='plasma_r', vmin=.8, vmax=1)
plt.tick_params(labelsize=17); plt.xlabel('Test context'); plt.ylabel('Train context')
plt.gcf().axes[-1].tick_params(labelsize=17)
plt.tight_layout(); plt.show()

# %% [markdown]
# ### POSTER PLOTS

# %%
fig, axes = plt.subplots(1, 3, figsize=(10,4.5))
plt.suptitle('Cross-context decoding accuracies -->', y=0.95)

# from matplotlib.cm import ScalarMappable; from matplotlib.colors import Normalize
# cax = fig.add_axes([0.35, 0.85, 0.30, 0.02]); sm = ScalarMappable(norm=Normalize(0, 1), cmap='Purples')
# cbar = fig.colorbar(sm, cax=cax, orientation='horizontal'); cbar.set_ticks([])
ctx_labels = conds

axes[0].set(xlabel='Test', ylabel='Train', title='Actual')
sns.heatmap(mean_net_acc, annot=True, fmt='.2f', annot_kws={'size': 15}, ax=axes[0],xticklabels=ctx_labels, yticklabels=ctx_labels, cmap='Purples', vmin=.8, vmax=1,cbar=False)

axes[1].set(title='Context shifts\nalong stimulus axis', ylabel='Accuracy', xlim=(0,.5),xticks=np.arange(0, 0.55, 0.25))
axes[1].plot(alphas, accs * 100, color='purple', lw=2)
axes[1].axvline(best_alpha, color='black', ls='--', label=f'α*={best_alpha:.2f}')

axes[2].set(xlabel='Test', ylabel='Train', title='Post-shift')
sns.heatmap(acc_opt, annot=True, fmt='.2f', annot_kws={'size': 15}, ax=axes[2],xticklabels=ctx_labels, yticklabels=ctx_labels, cmap='Purples', vmin=.8, vmax=1,cbar=False)
plt.tight_layout(w_pad=1)
# plt.savefig('../../outputs/figs/presentations/ccn/poster/representation2.svg', format='svg')  # poster fig on disk kept as is
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 5.5))
plt.suptitle('Cross-context decoding accuracy declines with context distance', y=0.95)

n_ctx = len(thresholds)
dist_idx = np.array([[abs(i - j) for j in range(n_ctx)] for i in range(n_ctx)])  # context distance = |train_idx - test_idx|

def net_by_distance(mat_stack):
    """(n_nets, n_ctx, n_ctx) -> (n_nets, n_ctx) accuracy averaged within each distance, per network."""
    return np.stack([mat_stack[:, dist_idx == d].mean(axis=1) for d in range(n_ctx)], axis=1)

def paired_line_plot(ax, mat_stack, title, color='purple'):
    """One line per network across the 3 context distances (paired data), plus a bold mean line.
    Falls back to a single mean-only line if only one matrix (no per-network data) is given."""
    single = (mat_stack.ndim == 2)
    per_unit = net_by_distance(mat_stack[None] if single else mat_stack)  # (n_units, n_ctx)
    if not single:
        for row in per_unit:
            ax.plot(range(n_ctx), row, color=color, alpha=0.15, lw=1)
    ax.plot(range(n_ctx), per_unit.mean(axis=0), color=color, lw=2.5, marker='o', ms=9, zorder=5)
    ax.set(title=title, xlabel='Context distance', ylabel='Accuracy', xticks=range(n_ctx), ylim=(0.75, 1.02))

paired_line_plot(axes[0], pairwise_acc, 'Actual')  # one line per network

axes[1].plot(alphas, accs * 100, color='purple', lw=2)
axes[1].axvline(best_alpha, color='black', ls='--', label=f'α*={best_alpha:.2f}')
axes[1].set(title='Context shifts\nalong stimulus axis', ylabel='Accuracy', xlim=(0,.5),xticks=np.arange(0, 0.55, 0.25))

paired_line_plot(axes[2], acc_opt, 'Post-shift')  # only a single matrix is available (no per-network version), so just the mean line

plt.tight_layout(w_pad=1)
# plt.savefig('../../outputs/figs/presentations/ccn/poster/representation2_lines.svg', format='svg')  # poster fig on disk kept as is
plt.show()
